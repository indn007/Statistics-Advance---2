# %% [markdown]
# # **Statistics Advance - 2**

# %% [markdown]
# # **Assignment Questions**

# %% [markdown]
# ###**1. What is hypothesis testing in statistics?**

# %% [markdown]
# **Ans:-** Hypothesis testing is a statistical method to determine if a sample provides enough evidence to reject a **null hypothesis (H₀)** in favor of an **alternative hypothesis (H₁)**. A **P-value** helps measure the likelihood of observing the data under H₀—if **P-value < α (e.g., 0.05)**, we reject H₀. Common tests include **Z-test, T-test, and Chi-square test**, used in fields like science, finance, and medicine

# %% [markdown]
# ###**2. What is the null hypothesis, and how does it differ from the alternative hypothesis?**

# %% [markdown]
# **Ans:-** The **null hypothesis (H₀)** is a statement that assumes **no effect or no difference** in a population—it suggests that any observed variation is due to chance. The **alternative hypothesis (H₁ or Hₐ)**, on the other hand, proposes that **there is an effect or a difference**, meaning the observed data is not just due to random chance.
#
# **Null Hypothesis (H₀)**
# * Assumes no effect or relationship
# * To be tested and possibly rejected
#
# **Example :-** "The average height of students is 5.5 ft."
#
# **Alternative Hypothesis (H₁)**
# * Suggests an effect or relationship exists
# * To be supported if H₀ is rejected
#
# **Example :-** "The average height of students is not 5.5 ft."

# %% [markdown]
# ###**3. What is the significance level in hypothesis testing, and why is it important?**

# %% [markdown]
# **Ans:-** The **significance level (α)** in hypothesis testing is the probability of rejecting the **null hypothesis (H₀)** when it is actually true. It represents the threshold for determining whether an observed effect is statistically significant.
#
# **Why is it important?**
# 1. **Controls Type I Error:** A lower α (e.g., 0.05) reduces the risk of falsely rejecting H₀.
#
# 2. **Defines Statistical Rigor:** Researchers set α (commonly 0.05 or 0.01) to ensure results are meaningful.
#
# 3. **Guides Decision-Making**: If **P-value < α**, we reject H₀, indicating strong evidence for the alternative hypothesis.

# %% [markdown]
# ###**4. What does a P-value represent in hypothesis testing?**

# %% [markdown]
# **Ans:-** A **P-value** in hypothesis testing represents the probability of obtaining results as extreme as the observed data, assuming the **null hypothesis (H₀)** is true. It helps determine whether the observed effect is statistically significant.
#
# **Key Points About P-Value:**
#
# 1. **Low P-value (< 0.05)** → Strong evidence against H₀ → Reject H₀.
#
# 2. **High P-value (> 0.05)** → Weak evidence against H₀ → Fail to reject H₀.
#
# 3. **It does not prove H₀ or H₁** but indicates the likelihood of observed data under H₀.

# %% [markdown]
# ###**5. How do you interpret the P-value in hypothesis testing?**

# %% [markdown]
# **Ans:-**
#
# 1. The **P-value** quantifies the probability of obtaining results as extreme as the observed data, assuming the null hypothesis (H₀) is true.
#
# 2. A **low P-value** (typically < 0.05) suggests that such extreme results are unlikely under H₀, providing strong evidence to reject it in favor of the **alternative hypothesis (H₁)**.
#
# 3. Conversely, a **high P-value** indicates that the observed data is consistent with H₀, meaning there isn’t enough evidence to reject the null hypothesis.

# %% [markdown]
# ###**6. What are Type 1 and Type 2 errors in hypothesis testing?**

# %% [markdown]
# **Ans:-** In hypothesis testing, **Type I and Type II errors** represent two kinds of mistakes you might make when drawing conclusions from sample data:
#
# 1. **Type I Error (False Positive)**: This occurs when you reject the null hypothesis (H₀) even though it is actually true. Essentially, it's like a false alarm—for example, concluding a drug is effective when it really isn’t. The significance level (α) you choose reflects the risk you're willing to take for this error.
#
# 2. **Type II Error (False Negative)**: This happens when you fail to reject the null hypothesis even though it is false. In other words, you miss detecting a true effect, such as not recognizing that a drug is effective when it actually is. The probability of a Type II error is denoted by β, and its complement (1 - β) is known as the test's power.

# %% [markdown]
# ###**7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?**

# %% [markdown]
# **Ans:-** A **one-tailed test** evaluates a hypothesis with a directional alternative—for example, testing if a parameter is either greater than or less than a specific value—so the entire significance level (α) is placed in one tail of the distribution. This approach is more powerful for detecting an effect in that specific direction but ignores deviations in the opposite direction .
#
# In contrast, a **two-tailed test** examines whether a parameter is simply different from a specified value by considering extreme outcomes in both directions. Here, the significance level is split between both tails, allowing detection of an effect regardless of its direction, which makes this test more conservative

# %% [markdown]
# ###**8. What is the Z-test, and when is it used in hypothesis testing?**

# %% [markdown]
# **Ans:-** The **Z-test** is used in hypothesis testing primarily to decide whether to reject the null hypothesis by comparing the observed sample statistic against the known population parameter. It is most appropriate when you have a large sample or when the population variance is available, making it simpler to use than the T-test, which is used when the sample size is small or the population standard deviation is unknown

# %% [markdown]
# ###**9. How do you calculate the Z-score, and what does it represent in hypothesis testing?**

# %% [markdown]
# 1. **Compare the Value to the Average**: Start by finding the difference between your observed value (like a sample mean) and the average (population mean or expected value). This tells you how much higher or lower your value is compared to what you normally expect.
#
# 2. **Understand the Variation**: Next, consider the typical amount of variation in your data—that is, how spread out your values usually are. This variation is what you’d expect from ordinary fluctuations or measurement differences.
#
# 3. **Gauge the Unusualness**: Finally, assess how many “steps” of this typical variation fit into the difference you observed. If the difference is small compared to the usual spread, your value is pretty ordinary. If it’s large, then it stands out. That “number of steps” is what the Z-score tells you—essentially, it’s a measure of how unusual your observation is relative to the normal variation in the data.

# %% [markdown]
# ###**10. What is the T-distribution, and when should it be used instead of the normal distribution?**

# %% [markdown]
# The **T-distribution** is a probability distribution that is similar to the normal distribution but has heavier tails. This means it gives more probability to events farther from the mean, accommodating the extra uncertainty that comes from estimating the population standard deviation using a small sample.
#
# You should use the T-distribution instead of the normal distribution when:
#
# * The sample size is small (commonly n < 30).
#
# * The population standard deviation is unknown—so you estimate it with the sample standard deviation.
#
# * The underlying data is approximately normally distributed.

# %% [markdown]
# ###**11. What is the difference between a Z-test and a T-test?**

# %% [markdown]
# A **Z-test** is used when you have a large sample size (typically n ≥ 30) or when the population standard deviation is known. In these cases, the sampling distribution of the mean is normally distributed, and the test statistic is based on the standard normal (Z) distribution.
#
# In contrast, a **T-test** is used when the sample size is small (typically n < 30) or when the population standard deviation is unknown. Here, you estimate the standard deviation from your sample, which adds extra uncertainty. The test statistic then follows a t-distribution with degrees of freedom that depend on your sample size, which has heavier tails than the normal distribution to account for this additional variability

# %% [markdown]
# ###**12. What is the T-test, and how is it used in hypothesis testing?**

# %% [markdown]
# **Ans:-** A **T-test** is a statistical method used to compare means when the population variance is unknown. It is especially useful when the sample size is small. The test calculates a t-statistic by measuring the difference between the sample mean and the hypothesized mean, adjusted by the sample's standard error. This t-statistic is then compared to a t-distribution with degrees of freedom equal to the sample size minus one. If the resulting p-value is below the chosen significance level, the null hypothesis is rejected.

# %% [markdown]
# ###**13. What is the relationship between Z-test and T-test in hypothesis testing?**

# %% [markdown]
# **Ans:-** Both the **Z-test** and **T-test** are used to assess whether a sample mean significantly differs from a hypothesized population mean. The Z-test is appropriate when the population standard deviation is known or when the sample size is large, allowing the Central Limit Theorem to ensure normality. In contrast, the T-test is used when the population standard deviation is unknown and the sample size is small; it compensates for the extra uncertainty by using the sample standard deviation and following a t-distribution. Essentially, the T-test is an adaptation of the Z-test that adjusts for increased variability in small samples. As the sample size grows, the t-distribution increasingly resembles the standard normal distribution, making the two tests converge.

# %% [markdown]
# ###**14. What is a confidence interval, and how is it used to interpret statistical results?**

# %% [markdown]
# **Ans:-** A **confidence interval (CI)** is a range derived from your sample data that estimates where the true population parameter (like a mean or proportion) is likely to fall. It is constructed by taking a point estimate and adding and subtracting a margin of error, which depends on the variability in the data and the chosen confidence level (e.g., 95%). A 95% CI indicates that if you were to take many samples, about 95% of the calculated intervals would contain the true population value. The width of the CI provides insight into the precision of your estimate—a narrower interval suggests higher precision, whereas a wider interval indicates more uncertainty. Confidence intervals help interpret statistical results by showing whether a hypothesized parameter value (such as a null value) falls within a plausible range; if it lies outside, it may signal a statistically significant difference.

# %% [markdown]
# ###**15. What is the margin of error, and how does it affect the confidence interval?**

# %% [markdown]
# **1.** The margin of error represents the "plus-or-minus" range around a sample estimate, reflecting the potential variability when estimating a population parameter.
#
# **2.** It is calculated by multiplying the standard error by a critical value corresponding to the chosen confidence level.
#
# **3.** When forming a confidence interval, you take your point estimate and add/subtract the margin of error to define the interval's bounds.
#
# **4.** A larger margin of error results in a wider confidence interval, indicating more uncertainty about the true parameter value.
#
# **5.** Conversely, a smaller margin of error produces a narrower interval, suggesting a more precise estimate of the population parameter.

# %% [markdown]
# ###**16. How is Bayes' Theorem used in statistics, and what is its significance?**

# %% [markdown]
# **Ans:-** **Bayes' Theorem** is used in statistics to update the probability of a hypothesis by combining prior beliefs with new evidence. It equates the posterior probability to the product of the likelihood (how probable the new evidence is given the hypothesis) and the prior probability, normalized by the overall probability of the evidence. This systematic updating process makes it invaluable for decision-making under uncertainty, allowing for more flexible and realistic models than methods that ignore prior knowledge. Its significance is also seen in diverse applications—from medical diagnoses to spam detection—where continually revising predictions based on emerging data is crucial. Overall, Bayes' Theorem underpins Bayesian inference, serving as a cornerstone for modern statistical analysis and decision theory

# %% [markdown]
# ###**17. What is the Chi-square distribution, and when is it used?**

# %% [markdown]
# The **Chi-square distribution** is a probability distribution that arises when summing the squares of independent standard normal variables. It is primarily used in hypothesis testing, especially for categorical data.
#
# **When is it used?**
# 1. **Chi-square goodness-of-fit test**: Determines if observed data matches an expected distribution.
#
# 2. **Chi-square test for independence**: Assesses whether two categorical variables are related.
#
# 3. **Variance estimation**: Used in confidence intervals for population variance when data follows a normal distribution.

# %% [markdown]
# ###**18. What is the Chi-square goodness of fit test, and how is it applied?**

# %% [markdown]
# The Chi-square goodness of fit test is a statistical method used to determine whether observed categorical data fit a specific expected distribution. It compares the observed frequencies in each category to the expected frequencies calculated from the hypothesized distribution to see how well the data “fits” that distribution.
#
# **How it is applied:**
#
#   **1. Set up hypotheses:**
#
#  * Null hypothesis (H₀): The observed data follows the expected distribution.
#
#  * Alternative hypothesis (H₁): The observed data does not follow the expected distribution.
#
# **Calculate expected frequencies** for each category based on the expected distribution.
#
# **Compute the Chi-square statistic** by measuring the differences between observed and expected frequencies.
#
# **Compare the test statistic** to the Chi-square distribution to decide whether to reject H₀, indicating whether the data fits the expected distribution or not.

# %% [markdown]
# ###**19. What is the F-distribution, and when is it used in hypothesis testing?**

# %% [markdown]
# The F-distribution is a continuous probability distribution that arises primarily in hypothesis testing and analysis of variance (ANOVA). It describes the ratio of two scaled chi-square distributed variables and is used to compare variances between groups. Specifically, it is used in ANOVA to test if group means are equal and in tests for equality of variances.

# %% [markdown]
# ###**20. What is an ANOVA test, and what are its assumptions?**

# %% [markdown]
# **ANOVA (Analysis of Variance)** is a statistical test used to determine if there are significant differences between the means of three or more groups.
#
# **The main assumptions of ANOVA are:**
#
# **1. Independence** of observations
#
# **2. Normality —** the data in each group should be approximately normally distributed
#
# **3. Homogeneity of variances —** the variances across groups should be equal

# %% [markdown]
# ###**21. What are the different types of ANOVA tests?**

# %% [markdown]
# **The main types of ANOVA tests are:**
#
# **1. One-way ANOVA:** Tests differences between means of three or more groups based on one factor.
#
# **2. Two-way ANOVA:** Tests the effect of two factors on the means, including interaction effects.
#
# **3. Repeated Measures ANOVA:** Tests means when the same subjects are measured multiple times under different conditions.

# %% [markdown]
# ###**22. What is the F-test, and how does it relate to hypothesis testing?**

# %% [markdown]
# The **F-test** is a statistical test that compares the variances of two populations using the ratio of their sample variances. It relates to hypothesis testing by evaluating whether the observed difference in variances is significant enough to reject the null hypothesis that the variances are equal.

# %% [markdown]
# # **Practical Part - 1**

# %% [markdown]
# ###**1. Write a Python program to generate a random variable and display its value?**

# %%
import random

# Generate a random floating-point number between 0 and 1
random_variable = random.random()

print(f"Generated Random Variable: {random_variable}")
# Out:
# Generated Random Variable: 0.7177276186631029

# %% [markdown]
# ###**2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the discrete uniform distribution (e.g., a fair six-sided die)
low = 1  # Inclusive lower bound
high = 7  # Exclusive upper bound (so 7 means the range is 1 to 6)
distribution = randint(low, high)

# Generate 10 random samples
samples = distribution.rvs(size=10)
print("Random Samples:", samples)

# Define the range of possible outcomes
x = np.arange(low, high)

# Calculate the PMF for each outcome
pmf_values = distribution.pmf(x)

# Plot the PMF
plt.bar(x, pmf_values, width=0.6, color='skyblue', edgecolor='black')
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xticks(x)
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Random Samples: [1 5 1 1 4 3 6 5 3 2]

# %% [markdown]
# ###**3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.**

# %%
from scipy.stats import bernoulli

def bernoulli_pmf(p, k):
    """
    Calculate the PMF of a Bernoulli distribution for a given probability p and outcome k.

    Parameters:
    - p (float): Probability of success (0 <= p <= 1).
    - k (int): Outcome (0 or 1).

    Returns:
    - float: Probability of observing outcome k.
    """
    if k not in [0, 1]:
        raise ValueError("Outcome k must be 0 or 1.")
    return bernoulli.pmf(k, p)

# Example usage:
p = 0.7  # Probability of success
for k in [0, 1]:
    probability = bernoulli_pmf(p, k)
    print(f"P(X = {k}) = {probability}")
# Out:
# P(X = 0) = 0.30000000000000004
# P(X = 1) = 0.7

# %% [markdown]
# ###**4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram?**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10      # Number of trials
p = 0.5     # Probability of success
size = 1000 # Number of simulations

# Simulate binomial distribution
samples = np.random.binomial(n, p, size)

# Plot histogram of simulated data
plt.hist(samples, bins=np.arange(n+2)-0.5, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Simulated Data')

# Calculate theoretical PMF
x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)

# Overlay theoretical PMF
plt.plot(x, pmf, 'o-', color='red', label='Theoretical PMF')

# Labels and title
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xticks(x)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ###**5. Create a Poisson distribution and visualize it using Python?**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the Poisson distribution parameter (λ = average events per interval)
lambda_val = 4

# Generate Poisson-distributed values
k_values = np.arange(0, 15)  # Possible number of occurrences
pmf_values = poisson.pmf(k_values, mu=lambda_val)  # Calculate PMF

# Plot the Poisson PMF
plt.bar(k_values, pmf_values, color='skyblue', edgecolor='black')
plt.xlabel('Number of Events (k)')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution (λ = {lambda_val})')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ###**6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discreteuniform distribution?**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the discrete uniform distribution (e.g., rolling a fair six-sided die)
low, high = 1, 6  # Possible outcomes: 1 to 6
distribution = randint(low, high + 1)

# Generate CDF values
x = np.arange(low, high + 1)
cdf_values = distribution.cdf(x)

# Plot the CDF
plt.step(x, cdf_values, where='post', color='blue', label='CDF')
plt.xlabel('Outcome')
plt.ylabel('Cumulative Probability')
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xticks(x)
plt.ylim(0, 1.05)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ###**7. Generate a continuous uniform distribution using NumPy and visualize it?**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters for the continuous uniform distribution
low, high = 0, 10  # Range of values
size = 10000  # Number of random samples

# Generate random samples
samples = np.random.uniform(low, high, size)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(samples, bins=50, density=True, alpha=0.6, color='g', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Continuous Uniform Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**8. Simulate data from a normal distribution and plot its histogram?**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters for the normal distribution
mean = 0  # Mean of the distribution
std_dev = 1  # Standard deviation
num_samples = 10000  # Number of samples

# Generate random samples from a normal distribution
data = np.random.normal(mean, std_dev, num_samples)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(data, bins=50, density=True, alpha=0.6, color='r', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Normally Distributed Data')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**9. Write a Python function to calculate Z-scores from a dataset and plot them?**

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculate Z-scores from a dataset and plot their histogram.

    Parameters:
    data (array-like): Input dataset (list, numpy array, etc.)

    Returns:
    z_scores (numpy array): Array of Z-scores
    """
    data = np.array(data)
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev

    # Plot histogram of Z-scores
    plt.figure(figsize=(8, 6))
    plt.hist(z_scores, bins=30, edgecolor='black', alpha=0.7)
    plt.title('Histogram of Z-Scores')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

    return z_scores

# Example usage
if __name__ == "__main__":
    # Generate example data (normal distribution)
    sample_data = np.random.normal(loc=50, scale=10, size=1000)
    z_scores = calculate_and_plot_z_scores(sample_data)

# %% [markdown]
# ###**10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create non-normal population (exponential distribution)
population = np.random.exponential(scale=2.0, size=10000)

# Take many samples and compute their means
sample_means = [np.mean(np.random.choice(population, size=30)) for _ in range(1000)]

# Plot the histogram of sample means
plt.hist(sample_means, bins=30, color='lightgreen', edgecolor='black')
plt.title('Central Limit Theorem Demonstration')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample means from a normal distribution
sample_means = [np.mean(np.random.normal(loc=50, scale=10, size=30)) for _ in range(1000)]

# Plot the histogram of sample means
plt.hist(sample_means, bins=30, color='lightblue', edgecolor='black')
plt.title('CLT: Sampling Distribution of Sample Means (Normal Data)')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).**

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_standard_normal():
    x = np.linspace(-4, 4, 100)
    y = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * x**2)

    plt.plot(x, y, color='green')
    plt.title('Standard Normal Distribution')
    plt.xlabel('x')
    plt.ylabel('Density')
    plt.grid(True)
    plt.show()

# Run the function
plot_standard_normal()

# %% [markdown]
# ###**13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.**

# %%
import numpy as np
from scipy.stats import binom

# Parameters
n = 10   # number of trials
p = 0.5  # probability of success

# Generate random binomial variables
data = np.random.binomial(n, p, size=10)
print("Random Binomial Values:", data)

# Calculate probabilities (PMF) for values 0 to n
x = np.arange(0, n+1)
probabilities = binom.pmf(x, n, p)

# Show probabilities
for val, prob in zip(x, probabilities):
    print(f"P(X = {val}) = {prob:.4f}")
# Out:
# Random Binomial Values: [4 5 6 5 7 4 6 4 4 7]
# P(X = 0) = 0.0010
# P(X = 1) = 0.0098
# P(X = 2) = 0.0439
# P(X = 3) = 0.1172
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
# P(X = 6) = 0.2051
# P(X = 7) = 0.1172
# P(X = 8) = 0.0439
# P(X = 9) = 0.0098
# P(X = 10) = 0.0010

# %% [markdown]
# ###**14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.**

# %%
import numpy as np
from scipy.stats import norm

# Example data
data = [60, 65, 70, 75, 80]
x = 75  # Data point to calculate Z-score for

# Calculate mean and standard deviation
mean = np.mean(data)
std = np.std(data)

# Calculate Z-score
z_score = (x - mean) / std
print(f"Z-score for x = {x}: {z_score:.2f}")

# Compare with standard normal distribution (find probability)
prob = norm.cdf(z_score)
print(f"Probability that a value is less than {x}: {prob:.4f}")
# Out:
# Z-score for x = 75: 0.71
# Probability that a value is less than 75: 0.7602

# %% [markdown]
# ###**15. Implement hypothesis testing using Z-statistics for a sample dataset.**

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = [102, 100, 98, 105, 101, 99, 97, 103, 104, 100]

# Known population parameters
pop_mean = 100
pop_std = 5

# Sample statistics
sample_mean = np.mean(sample)
sample_size = len(sample)

# Calculate Z-statistic
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
print(f"Z-statistic: {z:.3f}")

# Calculate two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z)))
print(f"P-value: {p_value:.4f}")

# Conclusion at alpha = 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference found.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Z-statistic: 0.569
# P-value: 0.5692
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
# ###**16. Create a confidence interval for a dataset using Python and interpret the result.**

# %%
import numpy as np
from scipy import stats

# Sample data
data = [12, 15, 14, 10, 13, 16, 12, 14, 15, 11]

# Calculate sample mean and standard error
mean = np.mean(data)
std_err = stats.sem(data)  # Standard error of the mean

# Confidence level
confidence = 0.95

# Calculate the confidence interval
ci = stats.t.interval(confidence, len(data)-1, loc=mean, scale=std_err)

print(f"Sample mean: {mean:.2f}")
print(f"95% Confidence Interval: ({ci[0]:.2f}, {ci[1]:.2f})")

# Interpretation
print(f"We are 95% confident that the true population mean lies between {ci[0]:.2f} and {ci[1]:.2f}.")
# Out:
# Sample mean: 13.20
# 95% Confidence Interval: (11.82, 14.58)
# We are 95% confident that the true population mean lies between 11.82 and 14.58.

# %% [markdown]
# ###**17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.**

# %%
import numpy as np
from scipy import stats

# Generate data from normal distribution (mean=50, std=5, size=30)
data = np.random.normal(loc=50, scale=5, size=30)

# Calculate sample mean and standard error
mean = np.mean(data)
std_err = stats.sem(data)

# Confidence level
confidence = 0.95

# Calculate confidence interval
ci = stats.t.interval(confidence, len(data)-1, loc=mean, scale=std_err)

print(f"Sample mean: {mean:.2f}")
print(f"95% Confidence Interval: ({ci[0]:.2f}, {ci[1]:.2f})")
print(f"We are 95% confident that the true population mean lies between {ci[0]:.2f} and {ci[1]:.2f}.")
# Out:
# Sample mean: 49.87
# 95% Confidence Interval: (47.88, 51.86)
# We are 95% confident that the true population mean lies between 47.88 and 51.86.

# %% [markdown]
# ###**18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
mean = 0
std_dev = 1

# Create x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100)

# Calculate PDF using the formula for normal distribution
pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean)/std_dev)**2)

# Plot the PDF
plt.plot(x, pdf, color='red')
plt.title('Normal Distribution PDF')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.**

# %%
from scipy.stats import poisson

# Parameters
lambda_ = 3  # average rate (mean) of events

# Calculate CDF for different values
x_values = range(0, 10)
cdf_values = [poisson.cdf(x, lambda_) for x in x_values]

# Print the results
for x, cdf in zip(x_values, cdf_values):
    print(f"P(X ≤ {x}) = {cdf:.4f}")

# Interpretation example:
print(f"\nInterpretation: The probability of observing up to 5 events is {poisson.cdf(5, lambda_):.4f}")
# Out:
# P(X ≤ 0) = 0.0498
# P(X ≤ 1) = 0.1991
# P(X ≤ 2) = 0.4232
# P(X ≤ 3) = 0.6472
# P(X ≤ 4) = 0.8153
# P(X ≤ 5) = 0.9161
# P(X ≤ 6) = 0.9665
# P(X ≤ 7) = 0.9881
# P(X ≤ 8) = 0.9962
# P(X ≤ 9) = 0.9989
#
# Interpretation: The probability of observing up to 5 events is 0.9161

# %% [markdown]
# ###**20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.**

# %%
import numpy as np

# Parameters for the uniform distribution
a = 0  # lower bound
b = 10  # upper bound

# Simulate a random variable
random_var = np.random.uniform(a, b)
print(f"Random variable from Uniform({a}, {b}): {random_var:.2f}")

# Calculate the expected value (mean) of the uniform distribution
expected_value = (a + b) / 2
print(f"Expected value of Uniform({a}, {b}): {expected_value}")
# Out:
# Random variable from Uniform(0, 10): 6.95
# Expected value of Uniform(0, 10): 5.0

# %% [markdown]
# ###**21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample datasets
data1 = [10, 12, 9, 14, 11, 13, 12]
data2 = [8, 7, 9, 6, 7, 5, 8]

# Calculate standard deviations
std1 = np.std(data1, ddof=1)  # sample std dev
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Visualization
datasets = ['Dataset 1', 'Dataset 2']
std_devs = [std1, std2]

plt.bar(datasets, std_devs, color=['blue', 'orange'])
plt.title('Comparison of Standard Deviations')
plt.ylabel('Standard Deviation')
plt.show()
# Out:
# Standard Deviation of Dataset 1: 1.72
# Standard Deviation of Dataset 2: 1.35

# %% [markdown]
# ###**22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.**

# %%
import numpy as np

# Generate data from normal distribution
data = np.random.normal(loc=50, scale=10, size=100)

# Calculate range
data_range = np.max(data) - np.min(data)

# Calculate interquartile range (IQR)
q75, q25 = np.percentile(data, [75 ,25])
iqr = q75 - q25

print(f"Range of the dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {iqr:.2f}")
# Out:
# Range of the dataset: 40.96
# Interquartile Range (IQR) of the dataset: 12.84

# %% [markdown]
# ###**23. Implement Z-score normalization on a dataset and visualize its transformation.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original dataset
data = np.array([10, 12, 9, 14, 11, 13, 12])

# Calculate mean and standard deviation
mean = np.mean(data)
std = np.std(data)

# Z-score normalization
z_scores = (data - mean) / std

# Plot before and after normalization
plt.figure(figsize=(10,4))

plt.subplot(1, 2, 1)
plt.hist(data, bins=5, color='skyblue', edgecolor='black')
plt.title('Original Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=5, color='salmon', edgecolor='black')
plt.title('Z-score Normalized Data')
plt.xlabel('Z-score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###**24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.**

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calc_skew_kurt():
    # Generate data from normal distribution
    data = np.random.normal(loc=0, scale=1, size=1000)

    # Calculate skewness and kurtosis
    skewness = skew(data)
    kurt = kurtosis(data)  # excess kurtosis (normal dist ~ 0)

    print(f"Skewness: {skewness:.4f}")
    print(f"Kurtosis: {kurt:.4f}")

# Call the function
calc_skew_kurt()
# Out:
# Skewness: 0.0170
# Kurtosis: -0.0899

# %% [markdown]
# # **Practical Part - 2**

# %% [markdown]
# ###**1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.**

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = [102, 100, 98, 105, 101, 99, 97, 103, 104, 100]

# Known population parameters
pop_mean = 100
pop_std = 5

# Sample statistics
sample_mean = np.mean(sample)
sample_size = len(sample)

# Calculate Z-statistic
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
print(f"Z-statistic: {z:.3f}")

# Calculate two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z)))
print(f"P-value: {p_value:.4f}")

# Interpret result at alpha = 0.05 significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from the population mean.")
# Out:
# Z-statistic: 0.569
# P-value: 0.5692
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %% [markdown]
# ###**2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.**

# %%
import numpy as np
from scipy.stats import norm

# Simulate random sample data (mean=50, std=10, size=30)
sample = np.random.normal(loc=50, scale=10, size=30)

# Known population parameters
pop_mean = 52
pop_std = 10

# Sample statistics
sample_mean = np.mean(sample)
sample_size = len(sample)

# Calculate Z-statistic
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
print(f"Z-statistic: {z:.3f}")

# Calculate two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z)))
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: significant difference found.")
else:
    print("Fail to reject the null hypothesis: no significant difference.")
# Out:
# Z-statistic: -2.394
# P-value: 0.0167
# Reject the null hypothesis: significant difference found.

# %% [markdown]
# ###**3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.**

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = [105, 102, 99, 101, 98, 100, 97, 103, 104, 106]

# Known population parameters
pop_mean = 100
pop_std = 5  # population standard deviation

# Sample statistics
sample_mean = np.mean(sample)
sample_size = len(sample)

# Calculate Z-statistic
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
print(f"Z-statistic: {z:.3f}")

# Calculate two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z)))
print(f"P-value: {p_value:.4f}")

# Interpret result at significance level 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: sample mean is significantly different from population mean.")
else:
    print("Fail to reject null hypothesis: no significant difference.")
# Out:
# Z-statistic: 0.949
# P-value: 0.3428
# Fail to reject null hypothesis: no significant difference.

# %% [markdown]
# ###**4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
sample = [105, 102, 99, 101, 98, 100, 97, 103, 104, 106]

# Known population parameters
pop_mean = 100
pop_std = 5
sample_size = len(sample)

# Calculate sample mean and Z-statistic
sample_mean = np.mean(sample)
z = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
print(f"Z-statistic: {z:.3f}")

# Significance level
alpha = 0.05

# Critical z-values for two-tailed test
z_critical_low = norm.ppf(alpha/2)
z_critical_high = norm.ppf(1 - alpha/2)

print(f"Critical Z-values: {z_critical_low:.3f}, {z_critical_high:.3f}")

# Calculate p-value
p_value = 2 * (1 - norm.cdf(abs(z)))
print(f"P-value: {p_value:.4f}")

# Plot the standard normal distribution
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y, label='Standard Normal Distribution')

# Shade rejection regions
plt.fill_between(x, 0, y, where=(x <= z_critical_low), color='red', alpha=0.3, label='Rejection Region')
plt.fill_between(x, 0, y, where=(x >= z_critical_high), color='red', alpha=0.3)

# Plot the calculated Z-statistic
plt.axvline(z, color='blue', linestyle='--', label=f'Z-statistic = {z:.2f}')

plt.title('Two-tailed Z-test')
plt.xlabel('Z value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# Decision
if z < z_critical_low or z > z_critical_high:
    print("Reject the null hypothesis: Significant difference.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Z-statistic: 0.949
# Critical Z-values: -1.960, 1.960
# P-value: 0.3428
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
# ###**5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_errors(mu0=0, mu1=1, sigma=1, n=30, alpha=0.05):
    """
    mu0: mean under null hypothesis
    mu1: mean under alternative hypothesis
    sigma: population standard deviation
    n: sample size
    alpha: significance level (Type 1 error rate)
    """
    # Standard error
    se = sigma / np.sqrt(n)

    # Critical z for two-tailed test
    z_crit_low = norm.ppf(alpha / 2)
    z_crit_high = norm.ppf(1 - alpha / 2)

    # Critical values in terms of sample mean
    crit_low = mu0 + z_crit_low * se
    crit_high = mu0 + z_crit_high * se

    # Type 1 error: reject H0 when true mean = mu0 (alpha)
    # Already set by critical values

    # Type 2 error: fail to reject H0 when true mean = mu1
    beta_low = norm.cdf(crit_low, loc=mu1, scale=se)
    beta_high = 1 - norm.cdf(crit_high, loc=mu1, scale=se)
    beta = beta_low + beta_high

    # Plotting
    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 1000)
    plt.plot(x, norm.pdf(x, mu0, se), label='H0 Distribution (mean=mu0)')
    plt.plot(x, norm.pdf(x, mu1, se), label='H1 Distribution (mean=mu1)')

    # Shade Type 1 error regions (tails of H0)
    plt.fill_between(x, 0, norm.pdf(x, mu0, se), where=(x <= crit_low), color='red', alpha=0.3, label='Type 1 Error (α)')
    plt.fill_between(x, 0, norm.pdf(x, mu0, se), where=(x >= crit_high), color='red', alpha=0.3)

    # Shade Type 2 error region (middle of H1)
    plt.fill_between(x, 0, norm.pdf(x, mu1, se), where=((x > crit_low) & (x < crit_high)), color='blue', alpha=0.3, label='Type 2 Error (β)')

    plt.title('Type 1 and Type 2 Errors Visualization')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"Significance level (Type 1 error, α): {alpha}")
    print(f"Type 2 error (β): {beta:.4f}")
    print(f"Power of the test (1 - β): {1 - beta:.4f}")

# Example usage
visualize_errors(mu0=0, mu1=1, sigma=1, n=30, alpha=0.05)
# Out:
# Significance level (Type 1 error, α): 0.05
# Type 2 error (β): 0.9998
# Power of the test (1 - β): 0.0002

# %% [markdown]
# ###**6. Write a Python program to perform an independent T-test and interpret the results.**

# %%
import numpy as np
from scipy.stats import ttest_ind

# Sample data for two groups
group1 = [23, 21, 19, 24, 22, 20, 25]
group2 = [30, 28, 32, 29, 31, 27, 33]

# Perform independent T-test
t_stat, p_value = ttest_ind(group1, group2)

print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Interpretation at significance level 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the two groups.")
# Out:
# T-statistic: -6.928
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between the two groups.

# %% [markdown]
# ###**7. Perform a paired sample T-test using Python and visualize the comparison results.**

# %%
import numpy as np
from scipy.stats import ttest_rel
import matplotlib.pyplot as plt

# Sample paired data (e.g., before and after treatment)
before = [85, 88, 90, 86, 87, 85, 89]
after = [88, 90, 92, 89, 90, 87, 91]

# Perform paired T-test
t_stat, p_value = ttest_rel(before, after)

print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Interpretation at 0.05 significance level
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: Significant difference between before and after.")
else:
    print("Fail to reject null hypothesis: No significant difference.")

# Visualization
plt.boxplot([before, after], labels=['Before', 'After'])
plt.title('Paired Sample Comparison')
plt.ylabel('Values')
plt.show()
# Out:
# T-statistic: -12.021
# P-value: 0.0000
# Reject null hypothesis: Significant difference between before and after.
# <ipython-input-35-ec2e49d58b72>:23: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([before, after], labels=['Before', 'After'])

# %% [markdown]
# ###**8. Simulate data and perform both Z-test and T-test, then compare the results using Python.**

# %%
import numpy as np
from scipy.stats import norm, t

# Simulate sample data
np.random.seed(0)
sample = np.random.normal(loc=105, scale=10, size=30)

# Known population parameters
pop_mean = 100
pop_std = 10  # population std dev

# Sample statistics
sample_mean = np.mean(sample)
sample_size = len(sample)
sample_std = np.std(sample, ddof=1)  # sample std dev

# Z-test calculation (using population std dev)
z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
p_value_z = 2 * (1 - norm.cdf(abs(z_stat)))

# T-test calculation (using sample std dev)
t_stat = (sample_mean - pop_mean) / (sample_std / np.sqrt(sample_size))
df = sample_size - 1
p_value_t = 2 * (1 - t.cdf(abs(t_stat), df))

print(f"Z-test statistic: {z_stat:.3f}, p-value: {p_value_z:.4f}")
print(f"T-test statistic: {t_stat:.3f}, p-value: {p_value_t:.4f}")

# Interpretation
alpha = 0.05
print("\nInterpretation at 0.05 significance level:")

if p_value_z < alpha:
    print("- Z-test: Reject null hypothesis (significant difference).")
else:
    print("- Z-test: Fail to reject null hypothesis (no significant difference).")

if p_value_t < alpha:
    print("- T-test: Reject null hypothesis (significant difference).")
else:
    print("- T-test: Fail to reject null hypothesis (no significant difference).")
# Out:
# Z-test statistic: 5.164, p-value: 0.0000
# T-test statistic: 4.693, p-value: 0.0001
#
# Interpretation at 0.05 significance level:
# - Z-test: Reject null hypothesis (significant difference).
# - T-test: Reject null hypothesis (significant difference).

# %% [markdown]
# ###**9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.**

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)

    # t-critical value for two-tailed test
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_crit * std_err
    lower = mean - margin_of_error
    upper = mean + margin_of_error

    return lower, upper

# Example usage
sample_data = [12, 15, 14, 10, 13, 15, 16, 14, 13, 12]
ci_lower, ci_upper = confidence_interval(sample_data)

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval: (12.13, 14.67)

# %% [markdown]
# ###**10. Write a Python program to calculate the margin of error for a given confidence level using sample data.**

# %%
import numpy as np
from scipy.stats import t

# Sample data
sample = [12, 15, 14, 10, 13, 15, 16, 14, 13, 12]

# Confidence level
confidence = 0.95

# Sample size, mean, and standard error
n = len(sample)
std_err = np.std(sample, ddof=1) / np.sqrt(n)

# t critical value for two-tailed test
t_crit = t.ppf((1 + confidence) / 2, df=n-1)

# Margin of error
margin_of_error = t_crit * std_err

print(f"Margin of Error at {confidence*100}% confidence level: {margin_of_error:.3f}")
# Out:
# Margin of Error at 95.0% confidence level: 1.271

# %% [markdown]
# ###**11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.**

# %%
def bayes_theorem(p_disease, p_pos_given_disease, p_no_disease, p_pos_given_no_disease):
    # Total probability of testing positive
    p_pos = p_pos_given_disease * p_disease + p_pos_given_no_disease * p_no_disease

    # Bayes' theorem formula
    p_disease_given_pos = (p_pos_given_disease * p_disease) / p_pos

    return p_disease_given_pos

# Given probabilities
p_disease = 0.01          # Prior probability of disease
p_no_disease = 1 - p_disease
p_pos_given_disease = 0.9  # Sensitivity
p_pos_given_no_disease = 0.05  # False positive rate

posterior = bayes_theorem(p_disease, p_pos_given_disease, p_no_disease, p_pos_given_no_disease)

print(f"Posterior probability of disease given positive test: {posterior:.4f}")
# Out:
# Posterior probability of disease given positive test: 0.1538

# %% [markdown]
# ###**12. Perform a Chi-square test for independence between two categorical variables in Python.**

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Example contingency table (e.g., Gender vs Preference)
# Rows: Male, Female
# Columns: Like, Dislike
data = np.array([[30, 10],
                 [20, 40]])

# Perform Chi-square test
chi2, p, dof, expected = chi2_contingency(data)

print(f"Chi-square statistic: {chi2:.3f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpretation
alpha = 0.05
if p < alpha:
    print("Reject null hypothesis: Variables are dependent (associated).")
else:
    print("Fail to reject null hypothesis: Variables are independent.")
# Out:
# Chi-square statistic: 15.042
# P-value: 0.0001
# Degrees of freedom: 1
# Expected frequencies:
# [[20. 20.]
#  [30. 30.]]
# Reject null hypothesis: Variables are dependent (associated).

# %% [markdown]
# ###**13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.**

# %%
import numpy as np

# Observed frequency table (contingency table)
observed = np.array([[30, 10],
                     [20, 40]])

# Calculate row sums, column sums, and total sum
row_sums = observed.sum(axis=1).reshape(-1, 1)
col_sums = observed.sum(axis=0).reshape(1, -1)
total = observed.sum()

# Calculate expected frequencies
expected = (row_sums @ col_sums) / total

print("Observed Frequencies:")
print(observed)
print("\nExpected Frequencies:")
print(expected)
# Out:
# Observed Frequencies:
# [[30 10]
#  [20 40]]
#
# Expected Frequencies:
# [[20. 20.]
#  [30. 30.]]

# %% [markdown]
# ###**14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.**

# %%
from scipy.stats import chisquare

# Observed frequencies (example)
observed = [50, 30, 20]

# Expected frequencies (same length as observed)
expected = [40, 40, 20]

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square statistic: {chi2_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: Observed data does not fit expected distribution.")
else:
    print("Fail to reject null hypothesis: Observed data fits expected distribution.")
# Out:
# Chi-square statistic: 5.000
# P-value: 0.0821
# Fail to reject null hypothesis: Observed data fits expected distribution.
